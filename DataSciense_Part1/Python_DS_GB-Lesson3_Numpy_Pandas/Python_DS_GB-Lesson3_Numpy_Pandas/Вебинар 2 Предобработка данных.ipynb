# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Получение-информации-о-данных" data-toc-modified-id="Получение-информации-о-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Получение информации о данных</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Обработка-редких-категорий" data-toc-modified-id="Обработка-редких-категорий-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обработка редких категорий</a></span></li><li><span><a href="#Обработка-выбросов" data-toc-modified-id="Обработка-выбросов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Обработка выбросов</a></span></li><li><span><a href="#Построение-новых-признаков" data-toc-modified-id="Построение-новых-признаков-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Построение новых признаков</a></span><ul class="toc-item"><li><span><a href="#Кодирование-категориальных-признаков" data-toc-modified-id="Кодирование-категориальных-признаков-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Кодирование категориальных признаков</a></span></li><li><span><a href="#Построение-новых-признаков-на-основе-количественных" data-toc-modified-id="Построение-новых-признаков-на-основе-количественных-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Построение новых признаков на основе количественных</a></span></li></ul></li><li><span><a href="#Ковариация-и-корреляция-данных" data-toc-modified-id="Ковариация-и-корреляция-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Ковариация и корреляция данных</a></span></li><li><span><a href="#Сохранение-результатов" data-toc-modified-id="Сохранение-результатов-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сохранение результатов</a></span></li></ul></div>

# %% [markdown]
# # Вебинар 2. Предобработка данных.

# %% [markdown]
# **Data Science проект:**
#
# 1. Постановка задачи
# 2. Получение данных
# _________
# 3. **Анализ данных**
# 4. Визуализация данных
# 5. **Предобработка данных**
# 6. **Генерация новых признаков**
# 7. Построение модели
# 8. Оценка качества
# ______
# 9. Внедрение модели
# 10. Мониторинг качества и улучшение модели

# %% [markdown]
# **Подключение библиотек и скриптов**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Пути к директориям и файлам**

# %%
DATASET_PATH = '../data/housing.csv'
PREPARED_DATASET_PATH = '../data/housing_prepared.csv'

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# **Описание датасета**
#
# Статистические данные о группах домов в Калифорнии, основанные на переписи 1990 года.
#
# A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
#
# * **longitude** - долгота группы
# * **latitude** - широта группы
# * **housing_median_age** - медианный возраст дома в группе (Median age of a house within a block)
# * **total_rooms** - общее количество комнат в группе домов (Total number of rooms within a block)
# * **total_bedrooms** - общее количество спален в группе домов (Total number of bedrooms within a block)
# * **population** - количество проживающих в группе домов (Total number of people residing within a block)
# * **households** - количество семей/общин (Total number of households, a group of people residing within a home unit, for a block)
# * **ocean_proximity** - близость океана
# * **median_income** - медианный доход общины (Median income for households within a block of houses, measured in tens of thousands of US Dollars)
# * **median_house_value** - медианная стоимость дома (Median house value for households within a block, measured in US Dollars)

# %%
df = pd.read_csv(DATASET_PATH, index_col='id')
df.head()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# id
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
#
#     population  households  median_income  median_house_value ocean_proximity
# id
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# ### Получение информации о данных

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  19918 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20041 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        19918.000000  20640.000000
# mean    -119.471242     35.036934           28.653630   2635.763081
# std        5.041408     94.903955           12.576796   2181.615252
# min     -124.350000 -13534.030000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max      122.030000   1327.130000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20041.000000  20640.000000   20640.000000
# mean       537.870553   1425.418243    499.539680       3.870671
# std        421.385070   1135.185798    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.describe(include='object')
# Out:
#        ocean_proximity
# count            20640
# unique               6
# top          <1H OCEAN
# freq              9127

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9127
# INLAND        6542
# NEAR OCEAN    2655
# NEAR BAY      2288
# -               23
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', '-', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df['ocean_proximity'].nunique()
# Out:
# 6

# %% [markdown]
# ### Обработка пропусков

# %%
len(df) - df.count()
# Out:
# longitude               0
# latitude                0
# housing_median_age    722
# total_rooms             0
# total_bedrooms        207
# population            599
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age    722
# total_rooms             0
# total_bedrooms        207
# population            599
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
round(df.isna().mean() * 100, 2)
# Out:
# longitude             0.0
# latitude              0.0
# housing_median_age    3.5
# total_rooms           0.0
# total_bedrooms        1.0
# population            2.9
# households            0.0
# median_income         0.0
# median_house_value    0.0
# ocean_proximity       0.0
# dtype: float64

# %% [markdown]
# **housing_median_age**

# %%
# 0 вариант замены - на константу
# df['housing_median_age'] = df['housing_median_age'].fillna(0)

# %%
df['housing_median_age'].mean(), df['housing_median_age'].median()
# Out:
# (28.653629882518324, 29.0)

# %%
# 1 вариант замены - на среднее арифметическое или медиану признака
# df['housing_median_age'] = df['housing_median_age'].fillna(df['housing_median_age'].mean())

# %%
# 2 вариант замены - на медиану признака в группе
df.groupby(['ocean_proximity'])['housing_median_age'].median()
# Out:
# ocean_proximity
# -             26.0
# <1H OCEAN     30.0
# INLAND        23.0
# ISLAND        52.0
# NEAR BAY      39.0
# NEAR OCEAN    29.0
# Name: housing_median_age, dtype: float64

# %%
df.loc[df['housing_median_age'].isna(), 'housing_median_age'] =\
    df.groupby(['ocean_proximity'])['housing_median_age'].transform(lambda x: x.median())

# %%
df['housing_median_age'].describe()
# Out:
# count    20640.000000
# mean        28.640455
# std         12.384944
# min          1.000000
# 25%         19.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %% [markdown]
# **total_bedrooms**

# %%
df['total_bedrooms'].fillna(df['total_bedrooms'].median(), inplace=True)

# %% [markdown]
# **population**

# %%
df['population'].fillna(df['population'].median(), inplace=True)

# %% [markdown]
# **ocean_proximity**

# %%
df['ocean_proximity'].mode()[0]
# Out:
# '<1H OCEAN'

# %%
df.replace({'ocean_proximity' : {'-' : df['ocean_proximity'].mode()[0]}}, inplace=True)

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9150
# INLAND        6542
# NEAR OCEAN    2655
# NEAR BAY      2288
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### Обработка редких категорий

# %%
df.replace({'ocean_proximity' : {'ISLAND' : 'NEAR OCEAN'}}, inplace=True)
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9150
# INLAND        6542
# NEAR OCEAN    2660
# NEAR BAY      2288
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### Обработка выбросов

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.471242     35.036934           28.640455   2635.763081
# std        5.041408     94.903955           12.384944   2181.615252
# min     -124.350000 -13534.030000            1.000000      2.000000
# 25%     -121.800000     33.930000           19.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max      122.030000   1327.130000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       536.838857   1417.860562    499.539680       3.870671
# std        419.391878   1119.445348    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# **longitude**
# [ссылка на карту](https://www.mapsdirections.info/ru/GPS-%D0%BA%D0%BE%D0%BE%D1%80%D0%B4%D0%B8%D0%BD%D0%B0%D1%82%D1%8B-Google-%D0%9A%D0%B0%D1%80%D1%82%D0%B0%D1%85.html)

# %%
df['longitude'].describe()
# Out:
# count    20640.000000
# mean      -119.471242
# std          5.041408
# min       -124.350000
# 25%       -121.800000
# 50%       -118.490000
# 75%       -118.010000
# max        122.030000
# Name: longitude, dtype: float64

# %%
df[(df['longitude'] < -125) | (df['longitude'] > -114)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# id
# 3479      118.51     34.29                29.0       1287.0           194.0
# 5904      118.43     34.29                39.0       1769.0           410.0
# 8405      118.36     33.93                40.0       1625.0           500.0
# 8636      118.41     33.88                43.0       2492.0           449.0
# 13051     121.29     38.61                17.0      13553.0          2474.0
# 15263     117.27     33.02                21.0       2144.0           340.0
# 17085       0.00     37.47                33.0       1266.0           415.0
# 17359       0.00     34.88                 4.0       3680.0           559.0
# 18551     122.03     36.96                28.0       1607.0           421.0
# 19423       0.00     37.69                 5.0       9601.0          1639.0
#
#        population  households  median_income  median_house_value  \
# id
# ...

# %%
df.loc[df['longitude'] > 0, 'longitude'] = df.loc[df['longitude'] > 0, 'longitude'] * -1

# %%
df.drop(df[df['longitude'] == 0].index, inplace=True)
df.shape
# Out:
# (20637, 10)

# %% [markdown]
# **latitude**

# %%
df[(df['latitude'] < 32) | (df['latitude'] > 42)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# id
# 8283     -118.13 -13534.03                45.0       1016.0           172.0
# 12772    -121.42   1327.13                23.0       2217.0           536.0
#
#        population  households  median_income  median_house_value  \
# id
# 8283        361.0       163.0         7.5000            434500.0
# 12772      1203.0       507.0         1.9412             73100.0
#
#       ocean_proximity
# id
# 8283       NEAR OCEAN
# 12772          INLAND

# %%
#df.loc[(df['latitude'] < 32) | (df['latitude'] > 42), 'latitude'] = df['latitude'].median()
df.drop(df[(df['latitude'] < 32) | (df['latitude'] > 42)].index, inplace=True)
df.shape
# Out:
# (20635, 10)

# %%
df.groupby('ocean_proximity')['latitude'].median()
# Out:
# ocean_proximity
# <1H OCEAN     34.03
# INLAND        36.97
# NEAR BAY      37.79
# NEAR OCEAN    33.79
# Name: latitude, dtype: float64

# %% [markdown]
# **'households', 'population', 'total_rooms', 'total_bedrooms'**

# %%
df[['households', 'population', 'total_rooms', 'total_bedrooms']].describe()
# Out:
#          households    population   total_rooms  total_bedrooms
# count  20635.000000  20635.000000  20635.000000    20635.000000
# mean     499.508166   1417.734916   2635.540102      536.807996
# std      382.293543   1119.348333   2181.276630      419.363925
# min        1.000000      3.000000      2.000000        1.000000
# 25%      280.000000    797.000000   1448.000000      297.000000
# 50%      409.000000   1165.000000   2127.000000      435.000000
# 75%      605.000000   1701.000000   3147.500000      643.500000
# max     6082.000000  35682.000000  39320.000000     6445.000000

# %% [markdown]
# ### Построение новых признаков

# %% [markdown]
# #### Кодирование категориальных признаков
# **Label Encoding**

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9149
# INLAND        6540
# NEAR OCEAN    2658
# NEAR BAY      2288
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# **Label Encoding**

# %%
dict = {'<1H OCEAN' : 1,
        'INLAND'    : 2,
        'NEAR OCEAN': 3,
        'NEAR BAY'  : 4}

df['ocean_proximity'].replace(dict, inplace=False).value_counts()
# Out:
# 1    9149
# 2    6540
# 3    2658
# 4    2288
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# **One-Hot Encoding**
#
# Преобразуем категориальный признак "ocean_proximity" в несколько бинарных

# %% [markdown]
# ![](oh.png)

# %%
ocean_pr = pd.get_dummies(df['ocean_proximity'])
ocean_pr
# Out:
#        <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# id
# 0              0       0         1           0
# 1              0       0         1           0
# 2              0       0         1           0
# 3              0       0         1           0
# 4              0       0         1           0
# ...          ...     ...       ...         ...
# 20635          0       1         0           0
# 20636          0       1         0           0
# 20637          0       1         0           0
# 20638          0       1         0           0
# 20639          0       1         0           0
#
# [20635 rows x 4 columns]

# %%
#df = pd.concat([df, ocean_pr], axis=1)
df[ocean_pr.columns] = ocean_pr
df.head()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# id
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
#
#     population  households  median_income  median_house_value ocean_proximity  \
# id
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
#
#     <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# ...

# %% [markdown]
# #### Построение новых признаков на основе количественных

# %%
df['rooms_per_household'] = df['total_rooms'] / df['households']
df['bedrooms_per_household'] = df['total_bedrooms'] / df['households']
df['persons_per_household'] = df['population'] / df['households']
df['income_per_person'] = df['median_income'] * 10000 / df['population']

# %%
df[['rooms_per_household', 'bedrooms_per_household', 
    'persons_per_household', 'income_per_person']].describe()
# Out:
#        rooms_per_household  bedrooms_per_household  persons_per_household  \
# count         20635.000000            20635.000000           20635.000000
# mean              5.429009                1.100916               3.110088
# std               2.474414                0.519220              10.489428
# min               0.846154                0.121204               0.324603
# 25%               4.440829                1.005525               2.422159
# 50%               5.229091                1.048860               2.817391
# 75%               6.052108                1.100029               3.289506
# max             141.909091               34.066667            1243.333333
#
#        income_per_person
# count       20635.000000
# mean           52.584734
# std           189.899675
# min             0.721064
# 25%            17.756294
# 50%            30.124317
# 75%            49.763999
# max         11538.538462

# %% [markdown]
# ### Ковариация и корреляция данных
#
# Используются для количественной оценки степени влияния признаков друг на друга.

# %% [markdown]
# Ковариация:
#
# $$cov(x,y)=\frac{\sum_i^n(x_i-\overline{x})(y_i-\overline{y})}{n-1}$$

# %%
df.cov()
# Out:
#                            longitude      latitude  housing_median_age  \
# longitude                   4.014369     -3.957263           -2.650270
# latitude                   -3.957263      4.562400            0.207061
# housing_median_age         -2.650270      0.207061          153.352054
# total_rooms               195.290045   -168.877855        -9491.972996
# total_bedrooms             58.182168    -59.701688        -1613.775911
# population                222.629014   -258.000217        -3950.847141
# households                 42.460777    -58.145590        -1396.090806
# median_income              -0.058231     -0.323270           -2.650003
# median_house_value     -10659.415299 -35499.998424       156577.167904
# <1H OCEAN                   0.319490     -0.473578            0.302256
# INLAND                     -0.052052      0.348712           -1.404580
# NEAR BAY                   -0.298417      0.240521            1.012889
# ...

# %% [markdown]
# Линейный коэффициент корреляции:
#
# $$R=\frac{cov(x,y)}{\sigma_x \sigma_y}$$

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col2 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col4 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col5 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_0b2c00f8_1252_11ec_b9d2_b4b52f8cd18erow0_col6 {
#             background-color:  #94b6ff;
#             color:  #000000;
# ...

# %%
df.corr()['median_house_value'].sort_values()
# Out:
# INLAND                   -0.484423
# latitude                 -0.144027
# longitude                -0.046104
# bedrooms_per_household   -0.045640
# population               -0.024150
# persons_per_household    -0.022960
# total_bedrooms            0.049568
# households                0.065964
# housing_median_age        0.109571
# income_per_person         0.114150
# total_rooms               0.134283
# NEAR OCEAN                0.142780
# rooms_per_household       0.151917
# NEAR BAY                  0.160569
# <1H OCEAN                 0.255942
# median_income             0.688016
# median_house_value        1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Сохранение результатов

# %%
#df.drop('ocean_proximity', axis=1, inplace=True)
df.head()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# id
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
#
#     population  households  median_income  median_house_value ocean_proximity  \
# id
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
#
# ...

# %%
df.to_csv(PREPARED_DATASET_PATH, index=False, encoding='utf-8')
