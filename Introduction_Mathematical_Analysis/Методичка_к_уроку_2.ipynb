# %% [markdown]
# # Урок 2

# %% [markdown]
# # Теория множеств. Математическая логика.

# %% [markdown]
# Любая научная дисциплина требует теории для её изучения. Для математического анализа и для любой другой математической дисциплины такой теорией является __теория множеств__. Исторически сложилась, что математический анализ в ВУЗах проходят одним из первых, поэтому с теорией множеств знакомятся вместе с математическим анализом.
#
# Исключений делать не будем.

# %% [markdown]
# ### Что такое теория?

# %% [markdown]
# Википедия говорит о том, что:
#
# __теория__  — это учение, система научного знания, описывающая и объясняющая некоторую совокупность явлений и сводящая открытые в данной области закономерные связи к единому объединяющему началу.
#
# По факту это действительно система, на которой построены, доказаны и сформулированы научные труды. При этом стоит отметить, что саму __теорию невозможно доказать или опровергнуть__. Ей можно только пользоваться. Как инструментом. В качестве сравнения можно представить строителя, у которого в арсенале много инструментов. Хороших или плохих. Выполняющих одни и те же функции или уникальных. Улучшающихся со временем.
#
# Большой вклад в современное восприятие теорий внес Гёдель Курт Фридрих. Выдвинув и доказав "теорему о неполноте" в 40-х годах XX века. Если говорить доступным языком, он доказал, что любая теория, состоящая их аксиом неполна и требует проверки теорией большего порядка.
#
# Это можно сравнить с измерением длины бруска с помощью линейки (а). Мы получим ответ при изменении, но он всегда будет иметь погрешность. Линейка (б), с меньшей ценой деления, даст более точный ответ, но опять не идеальных.
#
# <img src="https://i.ibb.co/SvYqVFf/1-1.png"  width = 500/>
#
# __То есть рано или поздно любая теория приводит к неразрешимостям или противоречиям внутри себя, что требует развитие новой или переосмысление старой теории.__

# %% [markdown]
# ### Теория множеств

# %% [markdown]
# Данная теория начала своё развитие в начале IX века и к началу XX стала такой, какой мы изучим её сегодня. Топливом же для развития послужило необходимость исследования бесконечности. Например, была надежда на исследования простых чисел на бесконечности. Но дальше исследований Римана никто ничего не предложил. Мы до сих пор не знаем по какому алгоритму создаются простые числа. На этом незнании, кстати, построена вся цифровая безопасность. То есть мы намерено создаем систему, которая может рухнуть с развитием математики.
#
# Понятие множества принадлежит к числу простейших математических понятий. Оно не имеет точного определения. Любое множество задается своими элементами. Примерами являются множество книг в библиотеке или множество студентов, присутствующих на занятии. Обычно:
#
# - множество обозначают заглавными латинскими буквами $(A)$;
# - его элементы строчными латинскими буквами $(a)$;
# - то, что элемент принадлежит множеству, обозначают так: $a\in A$;
# - если $a$ не принадлежит $A$, то этот факт обозначают так: $a\notin A$.
#
# Множества можно составлять из чего угодно, хоть из других множеств. Но чтобы не отдаляться от темы рассмотрим их на примере числовых множеств. Чтобы задать множество, следует или перечислить его элементы, или указать характеристическое свойство его элементов. То есть такое свойство, которым обладают все элементы множества и только они.
#
# Примеры.
#
# 1. Множество натуральных чисел можно задать так:
# ### $$\mathbb {N}=\{1, 2, 3,…,n, n+1,…\}$$
# Из записи следует, что все натуральные числа, начиная с двойки, получаются прибавлением единицы к предыдущему числу.
#
# 2. Множество целых чисел можно задать так:
# ### $$\mathbb {Z}=\{0, 1 ,–1, 2, –2,…,n, – n,…\} $$
#
# 3. Множество рациональных чисел можно задать так:
# ### $$\mathbb {Q}=\Bigr{\{}\frac{p}{q}\,\,\,\Bigr|\,\,\, p\in \mathbb {Z},q\in \mathbb {N}\Bigl{\}}$$
# Вертикальная черта внутри фигурной скобки означает, что далее идет описание характеристических свойств введенных обозначений.
#
# Два множества равны тогда и только тогда, когда состоят из одних и тех же элементов. Если же все элементы множества $A$ содержатся в множестве $B$, то говорят, что $A$ является подмножеством множества $B$ и обозначают $A\subset B$. Само же $B$ называют надмножеством множества $A$.
#
# __В данном курсе мы не будет изучать свойства множеств и надмножеством. В курсе линейной алгебры будут похожие темы, связанные с пространствами и подпространствами. Опустим понятие о мощности множества, а также какие множества называются индуктивными, рефлексивными или счётными. Это только добавит нагрузки на воспринимаемую информацию, при этом нигде не пригодится в дальнейшем.__
#
# В рамках рассматриваемой математической теории вводят два исключительных множества: пустое множество $(\emptyset)$, не содержащее элементов, и универсальное множество или «универсум» $(U)$, содержащее все элементы данной теории. При переводи аксиом теории множеств на математические дисциплины нулевой элемент как правило сохраняется. А существование бесконечности обычно заменяется существованием единицы и законов, с помощью которых эту бесконечность можно достичь.

# %% [markdown]
# ### Основные операции над множествами.
#
# 1. __Дополнение__. Для любого множества $A\subset U$ определим дополнение $A^c =\{b\in U \,\,|\,\,b\notin A\}$. Например, в множестве вещественных чисел дополнением к множеству $\mathbb {Q}$ является множество всех иррациональных чисел.
#
# 2. __Объединение__. Для любых двух множеств $A,B\subset U$ определим объединение $A\cup B =\{c\in U \,\,|\,\, (c\in A)\vee (c\in B)\}$. Значок $\vee$ внутри фигурной скобки называется __"дизъюнкция"__ , по смыслу максимально приближенная к союзу «или» (логическая сумма). Например, объединением отрезков $[1,3]$ и $[2,7]$ является отрезок $[1,7]$.
#
# 3. __Пересечение__. Для любых двух множеств $A,B\subset U$ определим пересечение $A\cap B =\{c\in U \,\,|\,\, (c\in A)\wedge(c\in B)\}$. Значок $\wedge$ внутри фигурной скобки называется __"конъюнкция"__, по смыслу максимально приближенная к союзу «и» (логическое произведение). Например, пересечением отрезков $[1,3]$ и $[2,7]$ является отрезок $[2,3]$.
#
# <img src="https://i.ibb.co/pWGqhCZ/1-2.png"  width = 600/>
#
# Для иллюстрации операций над множествами вводят диаграммы Эйлера-Венна – круги, обозначающие множества. Так, введенные нами операции иллюстрируются следующим образом. Подчеркнем, что диаграммы Эйлера-Венна не могут служить доказательствами равенства множеств.
#
# Кроме введенных нами трех операций над множествами существуют
# еще операции, которые могут быть представлены как комбинация
# простейших операций. Например:
#
# 4. __Разность__. Для любых двух множеств $A,B\subset U$ определим разность $A\setminus B =\{c\in U \,\,|\,\, (c\in A)\wedge(c\notin B)\}$. Например, разность отрезков $[1,3]$ и $[2,7]$ является отрезок $[1,2)$, причем не включая 2.
#
# 5. __Симметрическая разность__. Для любых двух множеств $A,B\subset U$ определим симметрическую разность $A\Delta B =\{c\in U \,\,|\,\, (c\in A)\oplus (c\notin B)\}$. Значок $\oplus$ внутри фигурной скобки имеет много названий. Мы будем называть __исключающее «или»__, его так же называют сложение по модулю 2, XOR, строгая дизъюнкция, поразрядное дополнение, инвертирование по маске, жегалкинское сложение, логическое вычитание, логическая неравнозначность. Например, симметрическая разность отрезков $[1,3]$ и $[2,7]$ является объединение двух отрезков $[1,2)\cup(3,7]$, причем не включая 2 и 3.
#
# <img src="https://i.ibb.co/L01w9dJ/1-3.png"  width = 400/>
#
# На python все операции реализованы следующим образом:

# %%
#Зададим множества А и В. Не обязательно числовые
A = {1, 2, 3, 4, 5, "десять", "двадцать"}
B = {4, 5, 6, 7, 8, "десять", "тридцать"}

# %%
# Объединение множеств можно проделать с помощью оператора "|" или функция union()
print(A | B)
print(B.union(A))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'десять', 'двадцать', 'тридцать'}
# {1, 2, 3, 4, 5, 6, 7, 8, 'десять', 'двадцать', 'тридцать'}

# %%
# Пересечение с помощью оператора "&" или функция intersection()
print(A & B)
print(B.intersection(A))
# Out:
# {'десять', 4, 5}
# {'десять', 4, 5}

# %%
# Разность с помощью оператора "-" или функция difference()
print(A - B)
print(B.difference(A))
print(A.difference(B))
# Out:
# {1, 2, 3, 'двадцать'}
# {8, 'тридцать', 6, 7}
# {1, 2, 3, 'двадцать'}

# %%
#Симметричную разность с помощью оператора "^" или функция symmetric_difference()
print(A ^ B)
print(A.symmetric_difference(B))
# Out:
# {1, 2, 3, 6, 7, 8, 'двадцать', 'тридцать'}
# {1, 2, 3, 6, 7, 8, 'двадцать', 'тридцать'}

# %%
#С помощью симметричной разности можно обменять значения множеств
 
A = {1, 2, 3, 4, 5, "десять", "двадцать"}
B = {4, 5, 6, 7, 8, "десять", "тридцать"}
A = A ^ B
B = A ^ B
A = A ^ B
print(A)
print(B)
# Out:
# {4, 5, 6, 7, 8, 'десять', 'тридцать'}
# {1, 2, 3, 4, 5, 'десять', 'двадцать'}

# %% [markdown]
# Также полезным будет знать что в теории множеств все операции над множествами можно разбить на два типа:
# - унарные (над одним множеством);
# - бинарные (между двумя множествами).
#
# Причем в сложных выражениях унарные операции имеют приоритет перед бинарными. Эти правила переходят во все математические дисциплины. А также в языки программирования. Например операция возведения в степень обычно имеет самый высокий приоритет, далее идет унарный минус и т.д..
#
# Унарные операции всегда производятся справа налево
#
# ### $${2^3}^2=2^9=512$$
#
# Бинарные операции всегда слева на право
#
# ### $$8\,/\,2\cdot3=4\cdot3=12$$

# %% [markdown]
# ### Основные законы теории множеств.
#
# 1. Коммутативность пересечения: $A\cap B = B\cap A$.
# 2. Коммутативность объединения: $A\cup B = B\cup A$.
# 3. Ассоциативность пересечения: $A\cap(B\cap C) = (A\cap B)\cap C$.
# 4. Ассоциативность объединения: $A\cup(B\cup C) = (A\cup B)\cup C$.
# 5. Дистрибутивность пересечения относительно объединения:
# $A\cap(B\cup C) = (A\cap B)\cup(A\cap C)$.
# 6. Дистрибутивность объединения относительно пересечения:
# $A\cup(B\cap C) = (A\cup B)\cap(A\cup C)$.
# 7. Закон де Моргана относительно пересечения: $(A\cap B)^c = A^c\cup B^c$.
# 8. Закон де Моргана относительно объединения: $(A\cup B)^c = A^c\cap B^c$.
# 9. Закон поглощения для объединения: $A\cup(A\cap B) = A$.
# 10. Закон поглощения для пересечения: $A\cap(A\cup B) = A$.
# 11. Закон идемпотентности для пересечения: $A\cap A= A$.
# 12. Закон идемпотентности для объединения: $A\cup A= A$.
# 13. Закон противоречия: $A\cap A^c =\emptyset$.
# 14. Закон исключения третьего: $A\cup A^c=U$.
# 15. Закон двойного отрицания: $(A^c)^c=A$.
# 16. $A\cap\emptyset=\emptyset ,\,\,\, A\cap U = A$.
# 17. $A\cup\emptyset=A ,\,\,\, A\cup U = U$.
#
# Данные законы нам известны еще со школьной парты на уроках алгебры. В любой математической дисциплине есть эти законы в определенной форме.
#
# В целом же изучение теории множеств на этом можно закончить. Потому что далее мы рассмотрим математическую логику и задачи, связанные с ней. Но в качестве дополнение разберем одну тему, частенько встречающуюся на собеседовании.
#
# ### Бесконечная десятичная периодическая дробь
#
# Мы уже успели рассмотреть множество рациональных чисел:
#
# ### $$\mathbb {Q}=\{\frac{p}{q}|\,\, p\in \mathbb {Z},q\in \mathbb {N}\}$$
#
# В школьном курсе математике при изучении рациональных чисел говорят о том, что любая бесконечная десятичная периодическая дробь является рациональным числом. То есть её можно записать в виде обыкновенной дроби. Давайте рассмотрим как это сделать.
#
# 1. Начнем с простого примера и представим $0.(3)$ в виде обыкновенной дроби. Для этого возьмем переменную $a=0.(3)$ и с помощью нее сместим разряд нашей дроби.
#
# ### $$a=0.(3)$$
#
# ### $$10a=3.(3)$$
#
# ### $$10a=3+0.(3)$$
#
# ### $$10a=3+a$$
#
# ### $$9a=3$$
#
# ### $$a=\frac{3}{9}=\frac{1}{3}$$
#
# ### $$0.(3)=\frac{1}{3}$$

# %%
print (1/3)
# Out:
# 0.3333333333333333

# %% [markdown]
# 2. Рассмотрим пример с $0.(18)$. Ход мысли будет тот же, только теперь нам нужно сместить два разряда.
#
# ### $$b=0.(18)$$
#
# ### $$100b=18.(18)$$
#
# ### $$100b=18+0.(18)$$
#
# ### $$100b=18+b$$
#
# ### $$99b=18$$
#
# ### $$b=\frac{18}{99}=\frac{2}{11}$$
#
# ### $$0.(18)=\frac{2}{11}$$

# %%
print (2/11)
# Out:
# 0.18181818181818182

# %% [markdown]
# 3. В самом сложном случаи бесконечная десятичная периодическая дробь может быть только частью числа  $1.32(18)$. В этом случаи нам нужно сместить разряд до бесконечной десятичной периодической дроби и найти ее значение отдельно.
#
# ### $$с=1.32(18)$$
#
# ### $$100с=132.(18)$$
#
# ### $$100с=132+0.(18)$$
#
# ### $$100с=132+\frac{2}{11}$$
#
# ### $$100с=\frac{1454}{11}$$
#
# ### $$с=\frac{1454}{1100}=\frac{727}{550}$$
#
# ### $$1.32(18)=\frac{727}{550}$$

# %%
print (727/550)
# Out:
# 1.3218181818181818

# %% [markdown]
# Есть в этой теории единственная не состыковка. Это число $0.(9)$. Попробуем представить его в виде обыкновенно дроби:
#
# ### $$d=0.(9)$$
#
# ### $$10d=9.(9)$$
#
# ### $$10d=9+0.(9)$$
#
# ### $$10d=9+d$$
#
# ### $$9d=9$$
#
# ### $$d=\frac{9}{9}=1$$
#
# ### $$0.(9)=1\,\,\,\,?$$
#
# В целом математическое общество смирилось с этим фактом и считают $0.(9)$ одной из форм записи числа $1$. Правда и вызывает ряд вопросов к нашей теории множеств.

# %% [markdown]
# ### Математическая логика
#
# __Математическая логика__ – разновидность формальной логики, то есть науки, которая изучает умозаключения с точки зрения их формального строения. Как наука математическая логика содержит множество разделов, например, теорию доказательств. Мы, в основном, познакомимся с наиболее простым разделом математической логики – с __логикой высказываний__. В этом разделе вопрос об истинности или ложности высказываний рассматривается и решается на основе изучения способа построения высказываний из так называемых элементарных высказываний с помощью логических операций или связок. __Основным понятием этого раздела логики естественно является высказывание__.
#
# Высказыванием называется повествовательное предложение, про которое всегда определенно можно сказать, является оно истинным (1) или ложным (0). Примеры высказываний: «2+2=4», «1+1=1»,«Земля вращается вокруг Солнца», «3>5», «10 – нечетное число», «На улице идет дождь». __Побудительные предложения («Кругом», «Идите к доске»), вопросительные («Сколько времени?») и восклицательные («Ак Барс –
# чемпион!») высказываниями не являются__. Логические операции на множестве высказываний задаются аксиоматически с применением таблиц истинности, указывающих значение (1 или 0) результата операции при задании значений исходных высказываний.

# %% [markdown]
# ### Аксиоматика операций над высказываниями.
#
# 1. __Отрицание__. Логическая операция, соответствующая логической связке «не» называется отрицанием. В результате этой операции получается высказывание ложное, если исходное высказывание истинно и истинное, если исходное ложно. Она обозначается $\overline A$ или $\neg A$ и читается «не $A$». Например, если $A$ – это высказывание «математическое утверждение доказано», то высказывание «математическое утверждение не доказано» обозначается $\overline A$. Соответствие между высказываниями определяется таблицами истинности. В нашем случае эта таблица имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$\overline A$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td></tr>
# </tbody>
# </table>
#
# 2. __Дизъюнкция__. Операция дизъюнкции применяется к двум высказываниям $А$ и $В$ и соответствует соединению их с помощью союза «или». Она обозначается $А || В$ или $А\vee В$ или $А+В$ (читается: $А$ или $В$). Например, «Договор может быть заключен в устной или письменной форме». Дизъюнкция двух высказываний $А$ и $В$ будет ложной тогда и только тогда, когда оба высказывания ложны. Поэтому таблица истинности для дизъюнкция имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\vee B$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# 3. __Конъюнкция__. Операция конъюнкции применяется к двум высказываниям $А$ и $В$ и соответствует соединению их с помощью союза «и». Она обозначается $А\, \&\& \,В$ или $А\wedge В$ или $А\cdot В$ (читается: $А$ и $В$). Например, «Он мой сокурсник и друг». Конъюнкция двух высказываний $А$ и $В$ будет истинной тогда и только тогда, когда истинны оба высказывания. Поэтому таблица истинности для конъюнкции имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\wedge B$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# Это основные операции. Рассмотрим дополнительные.
#
# 4. __Исключающее «или»__. Операция исключающее «или» применяется к двум высказываниям $А$ и $В$. Она обозначается $А\oplus В$(читается: $А$ исключающее «или» $В$). Например: «Либо пан, либо пропал». Данное высказывание истинно только в том случае, когда истинно только одно из элементарных высказываний. Таблица истинности имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\oplus B$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$0$</td></tr>
# </tbody>
# </table>
#
#
# 5. __Импликация__. Операция импликации соответствует объединению двух высказываний с помощью союза «если $А$ , то $В$». Она обозначается $А\rightarrow В$. Например, «Если студент-контрактник в течение 2-х сессий получал только отличные отметки, то по его ходатайству деканат может перевести его на бюджетную форму обучения». Импликация двух высказываний $А$ и $В$ ложна тогда и только тогда, когда высказывание $А$ истинно, а $В$ – ложно. Высказывание $А$ называется посылкой импликации, а высказывание $В$ – следствием. Таблица истинности имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\rightarrow B$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# Следует уточнить, что логическими операциями никак не учитывается смысл высказываний в них участвующих. Высказывания рассматриваются как объекты, обладающие единственным свойством быть истинными или ложными. Например: Пусть $Х$: «Луна сделана из зеленого сыра», а $У$: «2+2=5», тогда согласно таблице раз $Х$ ложно, то импликация $Х\rightarrow У$ будет истинна , хотя никакой связи по смыслу между $Х$ и $У$ нет. Точно так же, если $У$ – это «2+2=4», то $Х\rightarrow У$ – истинно , причем совершенно независимо от того есть ли связь между «Луна состоит из зеленого сыра» и «2+2=4». Такое уточнение смысла импликации «если $Х$, то $У$» не противоречит обыденному смыслу. Например обещание __«Если мне подарят велосипед, то я дам тебе покататься» воспринимается как ложь только в том случае, если мне подарили велосипед, а покататься на нем я не дал.__
#
#
# 6. __Эквиваленция__. Эквиваленция обозначается $А\leftrightarrow В$ (читается: $А$ эквивалентно $В$ или $А$ равносильно $В$ или $А$ тогда и только тогда, когда $В$). Например, «Четное число делится на 6 тогда и только тогда, когда оно делится на 3» или «Студент допускается к сессии в том и только в том случае, если он сдаст все зачеты». Эквиваленция двух высказываний $А$ и $В$ истинна тогда и только тогда, когда истинности высказываний совпадают. Поэтому таблица истинности для эквиваленции имеет вид:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\leftrightarrow B$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# Можно заметить, что эквиваленция и исключающее «или» имеют противоположные значение. Отсюда и появляется одно из названий исключающего «или» - логическая неравнозначность.

# %% [markdown]
# ### Основные законы логики высказываний ( аксиомы).
#
# 1. Коммутативность конъюнкции: $A\wedge B = B\wedge A$.
# 2. Коммутативность дизъюнкции: $A\vee B = B\vee A$.
# 3. Ассоциативность конъюнкции: $A\wedge(B\wedge C) = (A\wedge B)\wedge C$.
# 4. Ассоциативность дизъюнкции: $A\vee(B\vee C) = (A\vee B)\vee C$.
# 5. Дистрибутивность конъюнкции относительно дизъюнкции:
# $A\wedge(B\vee C) = (A\wedge B)\vee(A\wedge C)$.
# 6. Дистрибутивность дизъюнкции относительно конъюнкции:
# $A\vee(B\wedge C) = (A\vee B)\wedge(A\vee C)$.
# 7. Закон де Моргана относительно конъюнкции: $\overline{(A\wedge B)} =\overline A\vee \overline B$.
# 8. Закон де Моргана относительно дизъюнкции: $\overline{(A\vee B)} = \overline A\wedge \overline B$.
# 9. Закон поглощения для конъюнкции: $A\wedge(A\vee B) = A$.
# 10. Закон поглощения для дизъюнкции: $A\vee(A\wedge B) = A$.
# 11. Закон идемпотентности для конъюнкции: $A\wedge A= A$.
# 12. Закон идемпотентности для дизъюнкции: $A\vee A= A$.
# 13. Закон противоречия: $A\wedge \overline A=0$.
# 14. Закон исключения третьего: $A\vee \overline A=1$.
# 15. Закон двойного отрицания: $\overline {(\overline A)}=A$.
# 16. $A\wedge0=0 ,\,\,\, A\wedge 1 = A$.
# 17. $A\vee0=A ,\,\,\, A\vee 1 = 1$.

# %% [markdown]
# Опираясь на полученные знания можно выделить два подхода для работы с высказываниями:
#
# - с помощью основных законов логики высказываний;
# - с помощью таблицы истинности.
#
# Рассмотрим несколько примеров:
#
# 1. Упростить выражение
#
# ### $$\overline{(A\vee(A\wedge B))}\vee(A\vee(C\wedge \overline A))$$
#
# Решим данный пример с помощью основных законов логики высказываний. Это будет быстрее, чем использовать таблицы истинности, так как в выражение целых три элементарных высказывания $A$, $B$ и $C$ и придется рассмотреть $2^3=8$ случаев.
#
# ### $$\overline{(A\vee(A\wedge B))}\vee(A\vee(C\wedge \overline A))=$$
#
# ### $$=(\overline A\wedge\overline{(A\wedge B)})\vee((A\vee C)\wedge(A\vee\overline A))=$$
#
#
# ### $$=(\overline A\wedge(\overline A\vee \overline B))\vee((A\vee C)\wedge1)=$$
#
# ### $$=\overline A\vee(A\vee C)=$$
#
# ### $$=(\overline A\vee A)\vee C=1\vee C=1$$
#
# То есть выражение принимает истинное значение при любых значениях входящих в нее простых высказываний. __Такие выражения называют тавтологией__.
#
#  <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$С$</th><th>$(A\wedge B)$</th><th>$(A\vee(A\wedge B))$</th>
# <th>$\overline{(A\vee(A\wedge B))}$</th><th>$\overline A$</th><th>$(C\wedge \overline A)$</th><th>$(A\vee(C\wedge \overline A))$</th><th>$X$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$0$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$0$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td><td>$\,$</td></tr>
# </tbody>
# </table>

# %% [markdown]
# 2. Доказать, что при любых значениях $A$ и $B$ справедлива формула
#
# ### $$(A \rightarrow B) \leftrightarrow (\overline A \vee B)$$
#
#  Решим с помощью таблицы истинности:
#
#  <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A \rightarrow B$</th><th>$\overline A$</th><th>$\overline A\vee B$</th><th>$(A \rightarrow B) \leftrightarrow (\overline A\vee B)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# При любых $A$ и $B$ мы получаем истинное значение. Следовательно, формула является верной. С её помощью реализуется импликация в программировании, так как для импликации обычно нет собственного оператора.

# %% [markdown]
# Отойдем немного от темы и решим задачу на обычную логику, которая так же частенько встречается на собеседовании.
#
# 3. Рыцари всегда говорят правду, а лжецы всегда лгут. Представьте, что все лжецы острова живут в одном городе, а рыцари – в другом. Как выяснить у аборигена, куда ведет интересующая нас дорога – в город рыцарей или в город лжецов?
#
# Проблема задачи заключается в том, что мы не знаем кто перед нами: рыцарь или лжец. То есть ответ аборигена должен нас устроить в независимости от того: говорит он правду или лжет.
#
# Оказывается, достаточно задать один вопрос: "Какая дорога ведет в твой город?". Тогда и рыцарь, и лжец укажут на дорогу, ведущую к городу рыцарей. Тем самым мы и определимся с направлением пути.

# %% [markdown]
# ### Построение противоположного высказывания
#
# Пользуясь законами де Моргана, нетрудно определить правило, по которому строится высказывание, противоположное данному. Для построения противоположного высказывания, следует записать высказывание в виде формулы, а затем надчеркнуть эту формулу и упростить полученное высказывание, пользуясь доказанными законами математической логики.
#
# Очень часто в высказываниях (особенно, математических) присутствуют кванторы __всеобщности__ ($\forall$) или __существования__ ($\exists$). При построении противоположного высказывания данные кванторы взаимно заменяют друг друга. Поэтому правило построения высказывания, противоположного высказыванию, содержащему кванторы, такое. __В исходном высказывании выделяется основная фраза, которая содержится в последней части высказывания. При построении противоположного высказывания кванторы взаимно заменяются, а последняя фраза заменяется на противоположную.__
#
#
# #### Рассмотрим пример отрицания высказывания:
#
# 1. Каждого человека посещает мысль о том, что либо он должен поместить все деньги в банк, либо приобрести акции нефтяных компаний.
#
# $\forall$ человека __посещает__ мысль: (($\forall$ деньги __положить__ в банк) ∨ (__приобрести__ акции нефтяных компаний))
#
# $\exists$ человек __посещает__ мысль: (($\exists$ деньги, __не положенные__ в банк) ∧ (__не приобретать__ акции нефтяных компаний))
#
# Есть люди, твердо уверенные в том, что не все деньги следует
# доверять банкам и что нельзя покупать акции нефтяных компаний
#
# 2. Аналогичным способом строятся высказывания, противоположные математическим, таким как «Для любого $\varepsilon>0$ существует $\delta=\delta(\varepsilon)>0$ такое, что при любом $x$, обладающем свойством $|x|<\delta$, выполняется неравенство $|f(x)|<\varepsilon$».
#
# Запишем исходное высказывание в кванторах: «$\forall\varepsilon>0 \,\exists\delta=\delta(\varepsilon)>0$ такое, что $\forall x,|x|<\delta,(|f (x)|<\varepsilon)$».
#
# Противоположное высказывание в кванторах имеет вид «$\exists\varepsilon>0$ такое, что $ \forall\delta>0 \exists x,|x|<\delta,(|f (x)|\geq\varepsilon)$».
#
# Читается противоположное высказывание так: «существует такое $\varepsilon>0$ , что для любого положительного $\delta$ можно подобрать такое $x$ , что $|x|<\delta$ , и при
# этом $|f(x)|\geq\varepsilon$».
#
# Кстати, исходное высказывание – это математическое определение того факта, что функция $f(x)$ имеет в точке $x=0$ предел, равный $0$. Противоположное высказывание – это математическое определение того,
# что у функции $f(x)$ в точке $x=0$ либо не существует предела, либо есть предел, отличный от нуля. Но с этим будем уже разбираться в следующих уроках.

# %% [markdown]
# ### Резюме
#
# Вся современная математическая логика и как следствие компьютерная логика основана на философии древних греков. Где любое высказывание может быть либо строго истинным или строго ложным.
#
# Как показывает практика — это не всегда верно. Самым известным парадоксом в математические логики является "парадокс лжеца". Предположим я напишу фразу: «Я - ЛЖЕЦ» и скажу Вам что эта фраза является истинной. Можно ли выяснить кем я являюсь на самом деле?
#
# Рассматривая всего два возможных варианта лжеца и рыцаря, я не могу быть ни первым, ни вторым. А третьего в математической логике не дано!
#
# Подобные парадоксы или другие противоречия требуют от ученных развитие науки.
